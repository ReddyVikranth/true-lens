# %%
import os
import torch
import torchvision.models as models
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.optim as optim

# %%
img_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

# Real -> 0
# Fake -> 1
train_dataset = datasets.ImageFolder(root='../data/train', transform=img_transform)
test_dataset = datasets.ImageFolder(root='../data/test', transform=img_transform)
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
train_dataset[0][0].shape
# Out:
# torch.Size([3, 224, 224])

# %%
model = models.alexnet(pretrained=True)
# Out:
# c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=AlexNet_Weights.IMAGENET1K_V1`. You can also use `weights=AlexNet_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model.classifier[6] = nn.Linear(in_features=4096, out_features=2)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)
num_epochs = 10

# %%
for epoch in range(num_epochs):
    print(f"Epoch : {epoch}")
    for images, labels in train_loader:
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        print(f"Loss : {loss}")
        loss.backward()
        optimizer.step()
# Out:
# Epoch : 0
# Loss : 0.42595794796943665
# Loss : 0.5049305558204651
# Loss : 0.37565505504608154
# Loss : 0.4530867636203766
# Loss : 0.34242743253707886
# Loss : 0.6209762096405029
# Loss : 0.24187912046909332
# Loss : 0.3457341194152832
# Loss : 0.5253169536590576
# Loss : 0.3606575131416321
# Loss : 0.498906672000885
# Loss : 0.32003679871559143
# Loss : 0.5871257185935974
# Loss : 0.3261435031890869
# Loss : 0.2073674499988556
# Loss : 0.33453625440597534
# Loss : 0.4789360463619232
# Loss : 0.30136358737945557
# Loss : 0.3890266418457031
# Loss : 0.24929305911064148
# Loss : 0.38944554328918457
# Loss : 0.6421783566474915
# Loss : 0.25131702423095703
# Loss : 0.25520604848861694
# Loss : 0.3316085636615753
# Loss : 0.30135053396224976
# Loss : 0.2727978527545929
# Loss : 0.257118821144104
# Loss : 0.39185065031051636
# Loss : 0.3831106722354889
# Loss : 0.19478628039360046
# Loss : 0.23720702528953552
# Loss : 0.27921780943870544
# Loss : 0.23664560914039612
# Loss : 0.2184792459011078
# Loss : 0.2700991630554199
# Loss : 0.31570711731910706
# Loss : 0.17253920435905457
# Loss : 0.5017893314361572
# Loss : 0.18922267854213715
# Loss : 0.3588700592517853
# Loss : 0.41496655344963074
# Loss : 0.10889871418476105
# Loss : 0.3997371196746826
# Loss : 0.46225234866142273
# Loss : 0.23158040642738342
# Loss : 0.35596975684165955
# Loss : 0.3448779284954071
# Loss : 0.4770452082157135
# Loss : 0.32802391052246094
# Loss : 0.218336284160614
# Loss : 0.1882191002368927
# Loss : 0.2235327810049057
# Loss : 0.4192308485507965
# Loss : 0.185015469789505
# Loss : 0.21796470880508423
# Loss : 0.3352563977241516
# Loss : 0.23176050186157227
# Loss : 0.40765661001205444
# Loss : 0.1541796624660492
# Loss : 0.3757524788379669
# Loss : 0.31852832436561584
# Loss : 0.19255857169628143
# Loss : 0.26714009046554565
# Loss : 0.3275309205055237
# Loss : 0.6273905038833618
# Loss : 0.4848076403141022
# Loss : 0.2953849732875824
# Loss : 0.18515492975711823
# Loss : 0.11406665295362473
# Loss : 0.17370863258838654
# Loss : 0.38584569096565247
# Loss : 0.19081802666187286
# Loss : 0.3138119578361511
# Loss : 0.3108445107936859
# Loss : 0.2055230587720871
# Loss : 0.39196842908859253
# Loss : 0.3587568402290344
# Loss : 0.2061551958322525
# Loss : 0.16497093439102173
# Loss : 0.192379429936409
# Loss : 0.1859687864780426
# Loss : 0.1967829167842865
# Loss : 0.291329950094223
# Loss : 0.3200151026248932
# Loss : 0.14144228398799896
# Loss : 0.31478753685951233
# Loss : 0.33370810747146606
# Loss : 0.29229676723480225
# Loss : 0.1276952624320984
# Loss : 0.2666446268558502
# Loss : 0.3663581311702728
# Loss : 0.4489235579967499
# Loss : 0.43673503398895264
# Loss : 0.16310390830039978
# Loss : 0.28057751059532166
# Loss : 0.2792537212371826
# Loss : 0.2673409581184387
# Loss : 0.5510970950126648
# Loss : 0.37447428703308105
# Loss : 0.1979604959487915
# Loss : 0.24806943535804749
# Loss : 0.33286628127098083
# Loss : 0.4721300005912781
# Loss : 0.3842175602912903
# Loss : 0.1886395663022995
# Loss : 0.2391272634267807
# Loss : 0.4121382236480713
# Loss : 0.5038996338844299
# Loss : 0.37139222025871277
# Loss : 0.4764251708984375
# Loss : 0.27305296063423157
# Loss : 0.20278175175189972
# Loss : 0.3742060661315918
# Loss : 0.4405801296234131
# Loss : 0.47373947501182556
# Loss : 0.3115183413028717
# Loss : 0.35878893733024597
# Loss : 0.19759726524353027
# Loss : 0.2779139280319214
# Loss : 0.1928161233663559
# Loss : 0.26339295506477356
# Loss : 0.4140203297138214
# Loss : 0.16290365159511566
# Loss : 0.10196161270141602
# Loss : 0.39481446146965027
# Loss : 0.28048133850097656
# Loss : 0.1853724867105484
# Loss : 0.442665696144104
# Loss : 0.142754927277565
# Loss : 0.18755577504634857
# Loss : 0.13968001306056976
# Loss : 0.19948898255825043
# Loss : 0.16243985295295715
# Loss : 0.1983792781829834
# Loss : 0.19924548268318176
# Loss : 0.32952049374580383
# Loss : 0.223283052444458
# Loss : 0.07735913246870041
# Loss : 0.2931702136993408
# Loss : 0.27607977390289307
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[62], line 5
#       3 for images, labels in train_loader:
#       4     optimizer.zero_grad()
# ----> 5     outputs = model(images)
#       6     loss = criterion(outputs, labels)
#       7     print(f"Loss : {loss}")
#
# File c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torchvision\models\alexnet.py:48, in AlexNet.forward(self, x)
#      47 def forward(self, x: torch.Tensor) -> torch.Tensor:
# ---> 48     x = self.features(x)
#      49     x = self.avgpool(x)
#      50     x = torch.flatten(x, 1)
#
# File c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\container.py:240, in Sequential.forward(self, input)
#     238 def forward(self, input):
#     239     for module in self:
# --> 240         input = module(input)
#     241     return input
#
# File c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\conv.py:554, in Conv2d.forward(self, input)
#     553 def forward(self, input: Tensor) -> Tensor:
# --> 554     return self._conv_forward(input, self.weight, self.bias)
#
# File c:\Users\vikra\anaconda3\envs\myenv\Lib\site-packages\torch\nn\modules\conv.py:549, in Conv2d._conv_forward(self, input, weight, bias)
#     537 if self.padding_mode != "zeros":
#     538     return F.conv2d(
#     539         F.pad(
#     540             input, self._reversed_padding_repeated_twice, mode=self.padding_mode
#    (...)    547         self.groups,
#     548     )
# --> 549 return F.conv2d(
#     550     input, weight, bias, self.stride, self.padding, self.dilation, self.groups
#     551 )
#
# KeyboardInterrupt:
